# %% [markdown]
# <a href="https://colab.research.google.com/github/qgjoinlayo/EMTECH-1---CPE018/blob/main/PRELIM_EXAM___32_CIrcles_png.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Reads an image named "nature.jpg**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Load and Preprocess the image** **circles.png**

# %%
import cv2
from google.colab.patches import cv2_imshow

image_path = "/content/drive/MyDrive/ColabNotebooks/circles.png"
original_image = cv2.imread(image_path)

if original_image is None:
    print(f"Error: Could not load image from {image_path}. Please make sure the file exists.")
else:
    print(f"Image '{image_path}' SUCCESSSS")
    cv2_imshow(original_image)
    print("circles.png")
# Out:
# Image '/content/drive/MyDrive/ColabNotebooks/circles.png' SUCCESSSS
# <PIL.Image.Image image mode=RGB size=720x540>
# circles.png

# %% [markdown]
# ### **Detect circles using Hough Circle Transform**

# %%
import numpy as np

if original_image is not None:
    circles = cv2.HoughCircles(
        blurred_image,
        cv2.HOUGH_GRADIENT,
        dp=1,
        minDist=70,
        param1=150,
        param2=60,
        minRadius=20,
        maxRadius=200
    )

    image_with_circles = original_image.copy()
    if circles is not None:
        circles = np.uint16(np.around(circles))
        for i in circles[0, :]:
            cv2.circle(image_with_circles, (i[0], i[1]), i[2], (0, 0, 255), 2)
            cv2.circle(image_with_circles, (i[0], i[1]), 2, (0, 0, 255), 3)
        print(f"Detected {len(circles[0])} circles.")
    else:
        print("No circles detected.")

    cv2_imshow(image_with_circles)
    print("DETECTED CIRLES")
else:
    print("Cannot detect circles as the original image was not loaded.")
# Out:
# Detected 6 circles.
# <PIL.Image.Image image mode=RGB size=720x540>
# DETECTED CIRLES

# %% [markdown]
# ### **Save the result as** **circles_detected.png**

# %%
import numpy as np

if original_image is not None and circles is not None:
    output_path = "circles_detected.png"
    cv2.imwrite(output_path, image_with_circles)
    print(f"Processed image saved as {output_path}")
else:
    print("IT CANT")
# Out:
# Processed image saved as circles_detected.png
