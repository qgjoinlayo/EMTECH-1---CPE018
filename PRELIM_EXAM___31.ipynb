# %% [markdown]
# <a href="https://colab.research.google.com/github/qgjoinlayo/EMTECH-1---CPE018/blob/main/PRELIM_EXAM___31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Reads an image named "nature.jpg**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
img = cv2.imread("/content/drive/MyDrive/ColabNotebooks/nature.jpg")

# %% [markdown]
# **Converts it to grayscale**

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# #### **Displaying the grayscale image**

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=540x360>

# %% [markdown]
# **Resizes it to 300x300 pixels**

# %%
resized_img = cv2.resize(gray_img, (300, 300))
cv2_imshow(resized_img)
# Out:
# <PIL.Image.Image image mode=L size=300x300>

# %% [markdown]
# **Saves the result as "processed.jpg"**

# %%
output_path = "processed.jpg"
cv2.imwrite(output_path, resized_img)
print(f"Processed image saved as {output_path}")
# Out:
# Processed image saved as processed.jpg
